# %%
from transformers import AutoModelForCausalLM
from peft import PeftModel, PeftConfig
from huggingface_hub import login

login(token="HF_TOKEN_PLACEHOLDER")

# model_name = "facebook/opt-1.3b"
# model_name = "meta-llama/Meta-Llama-3.1-8B-Instruct"
model_name = "meta-llama/Llama-2-7b-hf"

# Load the base model
base_model = AutoModelForCausalLM.from_pretrained(model_name)

# Load the LoRA weights
peft_model = PeftModel.from_pretrained(
    base_model,  # Pass the base model object here
    "./llama-sft-lora-fsdp"  # Directory where LoRA weights are saved
)

# Push the LoRA weights to Hugging Face
peft_model.push_to_hub("sep_9")
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# adapter_model.safetensors:   0%|          | 0.00/80.0M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/example-user/sep_9/commit/dd5e3fb9944bfe7ce6f6f4e55d78e24091306306', commit_message='Upload model', commit_description='', oid='dd5e3fb9944bfe7ce6f6f4e55d78e24091306306', pr_url=None, pr_revision=None, pr_num=None)
